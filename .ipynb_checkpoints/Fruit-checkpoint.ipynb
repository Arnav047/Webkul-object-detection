# %%
# import os
# import requests
# from urllib.parse import quote

# PEXELS_API_KEY = 'BTfV1NN44sFozpnNNDh4483KO5hGpVgUekcqBX5z8wQJmkSXf8nCdXXu'  
# CLASSES = ['', 'fork']  
# NUM_IMAGES = 75  
# SAVE_DIR = 'dataset/images'  # Output folder

# HEADERS = {
#     'Authorization': PEXELS_API_KEY
# }

# def download_images_for_class(class_name):
#     os.makedirs(f'{SAVE_DIR}/{class_name}', exist_ok=True)
#     per_page = 15
#     page = 1
#     total_downloaded = 0

#     print(f"\n🔍 Downloading images for class: {class_name}")
#     while total_downloaded < NUM_IMAGES:
#         url = f'https://api.pexels.com/v1/search?query={quote(class_name)}&per_page={per_page}&page={page}'
#         response = requests.get(url, headers=HEADERS)

#         if response.status_code != 200:
#             print(f" Failed to fetch images for '{class_name}' (Status Code: {response.status_code})")
#             break

#         data = response.json()
#         photos = data.get('photos', [])
#         if not photos:
#             print(" No more images found.")
#             break

#         for photo in photos:
#             if total_downloaded >= NUM_IMAGES:
#                 break

#             image_url = photo['src']['original']
#             image_ext = image_url.split('.')[-1]
#             save_path = f"{SAVE_DIR}/{class_name}/{class_name}_{total_downloaded + 1}.{image_ext}"

#             img_data = requests.get(image_url).content
#             with open(save_path, 'wb') as handler:
#                 handler.write(img_data)

#             print(f"Downloaded: {save_path}")
#             total_downloaded += 1

#         page += 1

# if __name__ == "__main__":
#     for cls in CLASSES:
#         download_images_for_class(cls)

#     print("\n All images downloaded successfully!")

# %%
import os
import shutial
import random

DATASET_DIR = "dataset"
IMAGES_DIR = os.path.join(DATASET_DIR, "images")
LABELS_DIR = os.path.join(DATASET_DIR, "labels")

IMAGE_EXTS = ['.jpg', '.jpeg', '.png']  # lower case
SPLIT_RATIO = 0.8  # 80% train, 20% test

for split in ['train', 'test']:
    os.makedirs(os.path.join(IMAGES_DIR, split), exist_ok=True)
    os.makedirs(os.path.join(LABELS_DIR, split), exist_ok=True)

image_files = [
    f for f in os.listdir(IMAGES_DIR)
    if os.path.splitext(f)[1].lower() in IMAGE_EXTS
    and os.path.isfile(os.path.join(IMAGES_DIR, f))
]

random.shuffle(image_files)
split_idx = int(len(image_files) * SPLIT_RATIO)
train_images = image_files[:split_idx]
test_images = image_files[split_idx:]

def move_pair(files, split):
    for img in files:
        base = os.path.splitext(img)[0]
        img_path = os.path.join(IMAGES_DIR, img)
        label_path = os.path.join(LABELS_DIR, base + ".txt")

        img_dest = os.path.join(IMAGES_DIR, split, img)
        label_dest = os.path.join(LABELS_DIR, split, base + ".txt")

        shutil.move(img_path, img_dest)

        if os.path.exists(label_path):
            shutil.move(label_path, label_dest)
        else:
            print(f" Warning: No label found for {img}")

move_pair(train_images, 'train')
move_pair(test_images, 'test')

print("Dataset successfully split into train/test sets!")
# Out:
# ✅ Dataset successfully split into train/test sets!

# %%
# !pip install -U ultralytics

# %%
# !pip install --no-cache-dir torch torchvision torchaudio
# !pip install --no-cache-dir ultralytics

# %%
# !pip install ultralytics --quiet

# %%
# import sys
# !{sys.executable} -m pip install ultralytics --upgrade --quiet

# %%
from ultralytics import YOLO
print("Ultralytics YOLOv8 is ready to use!")
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\ADMIN\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✅ Ultralytics YOLOv8 is ready to use!

# %%
# from ultralytics import YOLO
# model = YOLO('yolov8n.pt')
# model.train(data='C:/Users/ADMIN/Documents/Custom Object Detector/dataset/data.yaml', epochs=50, imgsz=416, batch=4)

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt') 

model.train(
    data='C:/Users/ADMIN/Documents/Custom Object Detector/dataset/data.yaml',
    epochs=50,
    imgsz=416,
    batch=4,
    
    fliplr=0.5,          # Horizontal flip (common & safe)
    flipud=0.0,          # No vertical flip (unnatural for objects like fork/spoon)
    hsv_h=0.015,         # Hue variation
    hsv_s=0.5,           # Saturation (moderate)
    hsv_v=0.4,           # Brightness (moderate)
    translate=0.05,      # Slight translation
    scale=0.2,           # Slight zoom in/out
    shear=0.0,           # No shearing
    perspective=0.0,     # Disable to avoid geometric distortion
    mosaic=0.5,          # Enable mosaic moderately
    mixup=0.0,           # Disable MixUp (can confuse model on small datasets)
    copy_paste=0.0,      # Disable for now
    patience=10,
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.158 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.156  Python-3.11.0 torch-2.7.1+cpu CPU (Intel Core(TM) i5-1035G1 1.00GHz)
# ...

# %%
# %matplotlib inline
from PIL import Image
import matplotlib.pyplot as plt
import os

results_path = 'runs/detect/train/results.png'

if os.path.exists(results_path):
    img = Image.open(results_path)
    plt.figure(figsize=(10, 6))
    plt.imshow(img)
    plt.axis('off')
    plt.title("Training Results: Loss & mAP curves")
    plt.show()
else:
    print("results.png not found. Check your path or training output folder.")

# %%
metrics = model.val()
precision_per_class = metrics.box.p
recall_per_class = metrics.box.r
f1_per_class = metrics.box.f1

mean_precision = sum(precision_per_class) / len(precision_per_class)
mean_recall = sum(recall_per_class) / len(recall_per_class)
mean_f1 = sum(f1_per_class) / len(f1_per_class)

print("Precision per class:", precision_per_class)
print("Recall per class:", recall_per_class)
print("F1 score per class:", f1_per_class)

print("\nMean Precision:", round(mean_precision, 3))
print("Mean Recall:", round(mean_recall, 3))
print("Mean F1 Score:", round(mean_f1, 3))
# Out:
# Ultralytics 8.3.156  Python-3.11.0 torch-2.7.1+cpu CPU (Intel Core(TM) i5-1035G1 1.00GHz)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.60.2 ms, read: 53.534.9 MB/s, size: 159.5 KB)
# val: Scanning C:\Users\ADMIN\Documents\Custom Object Detector\dataset\labels\test.cache... 27 images, 0 backgrounds, 0
# C:\Users\ADMIN\myenv\Lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:03<0
#                    all         27         67        0.8      0.844      0.875       0.73
#                  apple          5          6          1      0.975      0.995      0.872
#                 orange          9         20       0.74      0.994      0.982      0.775
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train/weights/best.pt")  
results = model("dataset/images/test/Orange_39.jpg")  
results[0].save(filename="result_Orange_39.jpg")
# Out:
# image 1/1 C:\Users\ADMIN\Documents\Custom Object Detector\dataset\images\test\Orange_39.jpg: 288x416 4 oranges, 62.0ms
# Speed: 1.7ms preprocess, 62.0ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 416)
# 'result_Orange_39.jpg'

# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt

image_pairs = [
    ('dataset/images/test/apple_2.jpg', 'result_apple_2.jpg'),
    ('dataset/images/test/orange_23.jpg', 'result_orange_23.jpg'),
    ('dataset/images/test/Kiwi_6.jpg', 'result_Kiwi_6.jpg')  
]

plt.figure(figsize=(12, 4 * len(image_pairs)))

for i, (input_path, output_path) in enumerate(image_pairs):
    input_img = cv2.imread(input_path)
    input_rgb = cv2.cvtColor(input_img, cv2.COLOR_BGR2RGB) if input_img is not None else None

    output_img = cv2.imread(output_path)
    output_rgb = cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB) if output_img is not None else None

    plt.subplot(len(image_pairs), 2, 2 * i + 1)
    if input_rgb is not None:
        plt.imshow(input_rgb)
        plt.title(f"Input: {input_path.split('/')[-1]}")
    else:
        plt.text(0.5, 0.5, "Input Image Not Found", ha='center', va='center')
    plt.axis('off')

    plt.subplot(len(image_pairs), 2, 2 * i + 2)
    if output_rgb is not None:
        plt.imshow(output_rgb)
        plt.title(f"Output: {output_path.split('/')[-1]}")
    else:
        plt.text(0.5, 0.5, "Output Image Not Found", ha='center', va='center')
    plt.axis('off')

plt.tight_layout()
plt.show()
